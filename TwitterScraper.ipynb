# %% [markdown]
# <a href="https://colab.research.google.com/github/BrianGisemba/MENTAL-HEALTH-TWEETS-CLASSIFICATION/blob/Data-Scrapping/TwitterScraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#installing tweepy
# !pip install tweepy

# %%
#loading libraries
import os
import tweepy as tw

# %%
#initializing the token keys
consumer_key = '91LtHt5fNCABkeWzDDqQZG7eN'
consumer_secret = 'g1GTpyuGwxWL88LcYf0smr5BQCkVbdxHAu5wCICOT7hY7Ij2b3'
access_token = '771329002460082177-WsdjXnzEuexqRWLBXia9PPBpLmcUMN9'
access_token_secret = 'ImxLRfnQmMR8p6wVRkjyR5rWC8cAlFEEfq5jwFWnkUrzE'


auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth,wait_on_rate_limit=True)

# %%
#inputing the search words and geo 
search_words = ["depression"]
date_since = "2010-01-01"
geo = '-0.023559,37.906193,300km'

# %%
tweets = tw.Cursor(api.search,
                       q=search_words,
                       lang="en",
                       geocode=geo,
                       since=date_since).items(1000)
tweets

# %%
#creating the data frame
import pandas as pd
user = [[tweet.user.screen_name,
         tweet.text,
         tweet.user.location,
         tweet.user.description,
         tweet.user.friends_count,
         tweet.user.followers_count,
         tweet.user.statuses_count,
         tweet.created_at,
         tweet.retweet_count, 
         tweet.entities['hashtags']] for tweet in tweets]
user

tweet_text = pd.DataFrame(data=users_locs, 
                    columns=['user', 'tweet',"location", 'description','friends_count','followers_count', 
                             'statuses_count', 'created_at', 'retweet_count', 'hashtags'])
tweet_text
# Out:
#                user  ...                                           hashtags
# 0     TheKenyanPost  ...                                                 []
# 1       Goodguy_254  ...                                                 []
# 2        AlfredLete  ...                                                 []
# 3     GeraldNgaoPk7  ...  [{'text': 'ItumbiGhostWorkers', 'indices': [77...
# 4          swyma304  ...                                                 []
# ..              ...  ...                                                ...
# 348     jancan_limo  ...                                                 []
# 349  progirlsnation  ...  [{'text': 'progirlsnation', 'indices': [94, 10...
# 350       WillOdero  ...                                                 []
# 351        navywere  ...                                                 []
# 352        CbtKenya  ...                                                 []
#
# [353 rows x 10 columns]

# %%
tweet_text.tweet.head(1)
# Out:
# 0    SHOCK as a young man climbs on top of a hospit...
# Name: tweet, dtype: object

# %%
tweet_text['tweet']
# Out:
# 0      SHOCK as a young man climbs on top of a hospit...
# 1      People tend to hide depression under drinking ...
# 2                                @Lily_nganga Depression
# 3      Itumbi has subjected bloggers in to depression...
# 4      Mental health isn’t just anxiety &amp; depress...
#                              ...
# 348    @BikoSpeaks @arapronofelix If your job is help...
# 349    Cyber-bullying has driven people to depression...
# 350    Do most people recover from Depression or they...
# 351    We ask God to take away all the things not mea...
# 352    @ChiromoHospGrp @EdmondAgaba2 @KKwilbroad @ali...
# Name: tweet, Length: 353, dtype: object

# %%
tweet_text.to_csv("depression.csv")

# %%
tweet_text.created_at.unique()
# Out:
# array(['2021-08-17T10:33:55.000000000', '2021-08-17T10:20:30.000000000',
#        '2021-08-17T09:32:49.000000000', '2021-08-17T08:56:26.000000000',
#        '2021-08-17T08:18:20.000000000', '2021-08-17T08:08:05.000000000',
#        '2021-08-17T07:57:06.000000000', '2021-08-17T07:50:49.000000000',
#        '2021-08-17T07:37:23.000000000', '2021-08-17T07:20:09.000000000',
#        '2021-08-17T07:16:11.000000000', '2021-08-17T06:47:34.000000000',
#        '2021-08-17T06:47:11.000000000', '2021-08-17T06:44:00.000000000',
#        '2021-08-17T06:19:30.000000000', '2021-08-17T05:57:00.000000000',
#        '2021-08-17T05:48:26.000000000', '2021-08-17T05:22:17.000000000',
#        '2021-08-17T05:21:50.000000000', '2021-08-17T05:07:35.000000000',
#        '2021-08-17T05:06:25.000000000', '2021-08-16T22:49:22.000000000',
#        '2021-08-16T22:19:06.000000000', '2021-08-16T22:15:06.000000000',
#        '2021-08-16T20:58:48.000000000', '2021-08-16T20:01:22.000000000',
# ...
